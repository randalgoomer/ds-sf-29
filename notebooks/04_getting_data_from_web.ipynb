# %%
import sys
import requests     # how python goes onto the internet!
import re           # regex
from bs4 import BeautifulSoup # a python HTML parser (version 3)

# %%
import  bs4

# %%
# let's turn to stock prices
# http://finance.google.com/finance?q=aapl

# %%
symbol = 'aapl'

# %%
# Let's grab the raw html from the page
r = requests.get('http://finance.google.com/finance?q='+symbol) # the url of the google finance page goes in here

# %%
#b = BeautifulSoup(r.text,"html5lib")

# %%
# b = BeautifulSoup(r.text, "html5lib") # create a beautifulsoup object
b = BeautifulSoup(r.text, 'html.parser') # try this line instead if you have problems

# %%
b.prettify() # will print the html nicely
# Out:
# u'<!DOCTYPE html>\n<html>\n <head>\n  <script>\n   (function(){(function(){function e(a){this.t={};this.tick=function(a,c,b){var d=void 0!=b?b:(new Date).getTime();this.t[a]=[d,c];if(void 0==b)try{window.console.timeStamp("CSI/"+a)}catch(e){}};this.tick("start",null,a)}var a,d;window.performance&&(d=(a=window.performance.timing)&&a.responseStart);var f=0<d?new e(d):new e;window.jstiming={Timer:e,load:f};if(a){var c=a.navigationStart;0<c&&d>=c&&(window.jstiming.srt=d-c)}if(a){var b=window.jstiming.load;0<c&&d>=c&&(b.tick("_wtsrt",void 0,c),b.tick("wtsrt_","_wtsrt",\nd),b.tick("tbsd_","wtsrt_"))}try{a=null,window.chrome&&window.chrome.csi&&(a=Math.floor(window.chrome.csi().pageT),b&&0<c&&(b.tick("_tbnd",void 0,window.chrome.csi().startE),b.tick("tbnd_","_tbnd",c))),null==a&&window.gtbExternal&&(a=window.gtbExternal.pageT()),null==a&&window.external&&(a=window.external.pageT,b&&0<c&&(b.tick("_tbnd",void 0,window.external.startE),b.tick("tbnd_","_tbnd",c))),a&&(window.jstiming.pt=a)}catch(g){}})();})();\n  </script>\n  <title>\n   Apple Inc.: NASDAQ:AAPL quotes &amp; news - Google Finance\n  </title>\n  <meta content="Get detailed financial information on Apple Inc. (NASDAQ:AAPL) including real-time stock quotes, historical charts &amp; financial news, all for free!" name="Description">\n   <meta content="IE=10" http-equiv="X-UA-Compatible">\n    <link href="http://www.google.com/finance?cid=22144" rel="canonical">\n     <link href="/finance/f/finance_us-1489929081.css" rel="stylesheet" type="text/css">\n      <link href="/_/scs/finance-static/_/ss/k=finance.a.-1ad9g7dkeydo6.L.W.O/d=0/rs=AGHGApFc6f3qtgX-rKpnovDqtgcuZ4H2Ng" rel="stylesheet" type="text/css">\n       <link href="/finance/favicon.ico" rel="icon" type="image/vnd.microsoft.icon">\n        <style>\n         #gbar,#guser{font-size:13px;padding-right:8px;padding-top:4px !important;}#gbar{padding-left:8px;height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}\n        </style>\n        <script>\n        </script>\n        <script>\n         function _rpt() {}\n      function _tck() {}\n        </script>\n        <script>\n         (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n    ga(\'create\', \'UA-40765809-1\', {\n      \'allowLinker\': true,\n      \'cookiePath\': \'/finance\'\n    });\n    ga(\'send\', \'pageview\');\n        </script>\n       </link>\n      </link>\n     </link>\n    </link>\n   </meta>\n  </meta>\n </head>\n <body>\n  <div class="fjfe-bodywrapper">\n   <div class="g-doc" id="fjfe-real-body">\n    <input id="hist_state" name="hist_state" style="display:none;" type="text">\n     <iframe class="invfr" id="hist_frame" name="hist_frame" tabindex="-1">\n     </iframe>\n     <iframe class="invfr" src="/_/scs/finance-static/_/js/k=finance.a.en_US.0md5hz5pgeA.O/m=b/rt=h/d=0/rs=AGHGApHi_3j1v_Z6n816dUrW-04N4o1Vbg" tabindex="-1">\n     </iframe>\n     <div id="gbar">\n      <nobr>\n       <a class="gb1" href="https://www.google.com/webhp?tab=ew">\n        Search\n       </a>\n       <a class="gb1" href="http://www.google.com/imghp?hl=en&amp;tab=ei">\n        Images\n       </a>\n       <a class="gb1" href="http://maps.google.com/maps?hl=en&amp;tab=el">\n        Maps\n       </a>\n       <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=e8">\n        Play\n       </a>\n       <a class="gb1" href="http://www.youtube.com/?tab ...

# %%
# find all span tags
b.findAll('span')
# b.find_all('span') for bs4 users
# Out:
# [<span class="gbi" id="gbn"></span>,
#  <span class="gbf" id="gbf"></span>,
#  <span id="gbe"></span>,
#  <span class="fjfe-searchbox-button-wrapper"><span class="fjfe-searchbox-button-wrapper2"><input class="fjfe-searchbox-button" tabindex="2" type="submit" value="Get quotes"/></span></span>,
#  <span class="fjfe-searchbox-button-wrapper2"><input class="fjfe-searchbox-button" tabindex="2" type="submit" value="Get quotes"/></span>,
#  <span class="fjfe-recentquotes-duration">(<a href="//www.google.com/history/optout?hl=en">30 days</a>)</span>,
#  <span class="fjfe-chg-toggle">chg</span>,
#  <span class="fjfe-perc-toggle">%</span>,
#  <span class="pr">\n<span id="ref_22144_l">111.23</span>\n</span>,
#  <span id="ref_22144_l">111.23</span>,
#  <span class="ch bld"><span class="chr" id="ref_22144_c">-0.57</span>\n<span class="chr" id="ref_22144_cp">(-0.51%)</span>\n</span>,
#  <span class="chr" id="ref_22144_c">-0.57</span>,
#  <span class="chr" id="ref_22144_cp">(-0.51%)</span>,
#  <span class="bld" id="ref_22144_el">111.22</span>,
#  <span class="chr" id="ref_22144_ec">-0.01</span>,
#  <span class="chr" id="ref_22144_ecp">(-0.01%)</span>,
#  <span class="dis-large"><nobr>NASDAQ\nreal-time data -\n<a class="dis-large" href="//www.google.com/help/stock_disclaimer.html#realtime">Disclaimer</a>\n</nobr></span>,
#  <span class="settings-link">Settings</span>,
#  <span class="technicals-link">Technicals</span>,
#  <span style="white-space:nowrap;">\n<img alt="Link to chart icon." class="linktochart-img SP_link" hight="9" src="/finance/s/m4C5KaofCbA/images/cleardot.gif" width="16"/>\n<span class="linktochart-link">\nLink to this view</span>\n</span>,
#  <span class="linktochart-link">\nLink to this view</span>,
#  <span class="chart-dis">Volume delayed by 15 mins.<br>Prices are not from all markets.<br>Sources include SIX.<br>\n</br></br></br></span>,
#  <span class="id-related-edit-col linkbtn">Add or remove columns</span>]

# %%
# the pattern we recognized from the website
re_tag = re.compile("ref_\d+_l")

# %%
#this tag finds the tag with the price in it!!!!
span_tag = b.find('span', attrs={'id': re_tag}) 
# use find to return THE ONE AND ONLY span tags with an id that matches our regex
# use findAll to find all matches

# %%
quote = span_tag.text
quote
# Out:
# u'111.23'

# %%
##### EXERCISE #####
# Make a method  get_stock_price that takes in ANY stock ticker and grabs the current price
# If the stock ticker doesn't exist, return -1

# %%
def get_stock_price(ticker):
    response = requests.get("http://google.com/finance?q="+ticker)
    parser = BeautifulSoup(response.text, "html.parser")
    pattern = re.compile("ref_\d+_l")
    span_tag = parser.find("span", attrs={"id":pattern})
    if span_tag:
        return span_tag.text
    else:
        return -1

# %%
for ticker in ['ge', 'spy', 'fb','rtn']:
    print get_stock_price(ticker)
# Out:
# 31.34
# 220.70
# 120.84
# 147.88

# %%
response = requests.get("http://www.nytimes.com/")
parser = BeautifulSoup(response.text, "html.parser")
for story in parser.findAll("h2", attrs={'class':'story-heading'}):
    print story.text
# Out:
# Trump Moves to Diversify His Cabinet With Latest Picks
# Haley’s Path: From Daughter of Immigrants to Pick for U.N. 3:37 PM ET
# ‘Lock Her Up’? He’d Rather Move On
# Transition Briefing: Clinton’s Lead Grows in Popular Vote 3:48 PM ET
# Trump Tempers Views but Defies Standards
# A Less Combative Trump Says, ‘I Hope We Can All Get Along’
# Trump’s Times Interview: The Full Transcript
# Audio: Inside the Room With the President-Elect
# Those Accused of Postelection Harassment, in Their Own Words
# Two Children, One Rich, One Poor, Gasping for Air
# Koch Brothers Are Winners in Fight Over Madoff Riches
# ‘Ridiculed for Eight Years,’ Gun Owners Expect Shift in Tone
#
#                                     A Burmese Take on American Thanksgiving
# The Conflicts Along the Dakota Pipeline
# Your Thursday Briefing
# California Today: Opting to Pass on Thanksgiving Politics
#
# How to Cook Turkey
# How to Make Pie Crust
# Ralph Branca, ‘Shot Heard Round the World’ Pitcher, Dies
# It’s Doctor’s Orders, but Will Insurers Pay for Marijuana?
# Searching the Sky for Bombs in Aleppo
#
# Cuomo’s Commitment to Clemency Tested in Murder Cases
# Eli Lilly Alzheimer’s Drug Failed in Large Trial 12:11 PM ET
# Turkey and E.U. Near Freeze in Membership Talks
# India and Pakistan Intensify Fighting in Kashmir 3:32 PM ET
# Public Editor: The Times Should Eliminate Fake-News Ads
#
# Book Review: Civilian Life in Europe Under Hitler
#
#
# The Thrill of High-School Football Games
#
#
# For a Bargain Vacation, Don’t Rule Out Hawaii
#
# The Farmers We Forgot
# The Politics of Identity
# Editorial: America Has Room for the Dreamers
# Dreamers: Share Your Story
# My Life With Tourette’s Syndrome
# Editorial: Questioning Trump
# Bruni: His Demand for Love
# Douthat: Trump Revelations
# Friedman: Giving Critics Hope
# Leonhardt: Our Free Press
# Letters: Trump’s Visit 1:47 PM ET
#
# Optimistic, Pessimistic, Neutral: How Do Times Readers Feel, Post-Election?
#
#
# Good, Bad and Mad: The Opinion Columnist Andrew Rosenthal on the News
#
#
# Optimistic, Pessimistic, Neutral: How Do Times Readers Feel, Post-Election?
#
#
# Play Today’s Puzzle
#
#
# Play Today’s Puzzle
#
#
# Come On Along With Us
#
# A Reunion 21 Years in the Making
# Models With Down Syndrome More Visible
# Op-Ed: Brexit Triple-Plus, Britain Nonplused
# The Power of Play
# The Politics of Identity
# Night Out: Lauren Graham’s Taste of Tokyo
# For Deaf Tennis Player, Sound Is No Barrier
# Thomas Friedman’s Message: It Will Be O.K.
# Editorial: Power Imbalance at the Pipeline
# Lens: Miss Sharon Jones, Queen Among Dap-Kings
# My Life With Tourette’s Syndrome
# A Four-Day Feast in Philadelphia
# The Identity Politics of Whiteness
#
#
#             Two Children, One Rich, One Poor, Gasping for Air in Delhi’s Smog
#
#
#
#             Land Mine Casualties Jump 75% as Funding for Their Removal Declines
#
#
#
#             Book Publishers Scramble to Make Sense of Trump’s Rise to Victory
#
#
#
#             Wall St. Closes Mostly Higher
#
#
#
#             Editorial: Questioning Donald Trump
#
#
#
#             Frank Bruni: Donald Trump’s Demand for Love
#
#
#
#             Donald Trump’s Early Backers in State Government May See Rewards
#
#
#
#             Those Accused of Postelection Harassment, in Their Own Words
#
#
#
#             James Simons’s Foundation Starts New Institute for Computing, Big Data
#
#
#
#             Fake News Onslaught Targets Pizzeria as Nest of Child-Trafficking
#
#
#
#             Long Before ‘Hamilton’ Brouhaha, Theater Was Anything but Polite
#
#
#
#             Alvin Ailey’s Robert Battle on His First Real Dance Shoes
#
#
#
#             Bloomberg Says Cities Will Fight Climate Change, With or Without Trump
#
#
#
#             Trump Diversifies Cabinet; Picks Nikki Haley and Betsy DeVos
#
#
#
#             Modern Love: The Modern Love Podcast: Molly Ringwald Reads ‘From Divorce, a Fractured Beauty’
#
#
#
#             2016 Holiday Gift Guide
#
#
#
#             Review: ‘Moana,’ Brave Princess on a Voyage With a Chicken
#
#
#
#             Review: ‘Allied,’ With Brad Pitt and Marion Cotillard, Uncorks a Favorite Vintage
#
#
#
#             About New York: Cuomo’s Commitment to Clemency Tested in 3 Murder Cases
#
#
#
#             Ex-Advisers to Gov. Andrew M. Cuomo Are Indicted in Federal Bribery Case
#
#
#
#             The 10 Most Important N.F.L. Games (One of Them Is on Thursday)
#
#
#
#             Five Years After Scandal, Jim Tressel Is Still a Buckeye
#
#
#
#             Critic’s Notebook: Watching Postelection, So Much Feels Different
#
#
#
#             How to Master an Accent
#
#
#
#             Trilobites: Thanksgiving Turkeys May Have Been Tamed 1,500 Years Ago in Mexico
#
#
#
#             Out There: Telescope That ‘Ate Astronomy’ Is on Track to Surpass Hubble
#
#
#
#             Whitney Smith, Whose Passion for Flags Became a Career, Dies at 76
#
#
#
#             Peter Binzen, Dean of Philadelphia Journalism for Half a Century, Dies at 94
#
#
#
#             Critic's Notebook: Weathering a Blizzard of Christmas TV Programming
#
#
#
#             Tina Brown on the Final Two Episodes of ‘The Crown’: Love and Duty
#
#
#
#             Microcephaly Found in Babies of Zika-Infected Mothers Months After Birth
#
#
#
#             Eli Lilly’s Experimental Alzheimer’s Drug Failed in Large Trial
#
#
#
#             Frugal Traveler: In Hong Kong’s Kowloon, the Markets Rule
#
#
#
#             2016 Holiday Gift Guide - Travel
#
#
#
#             Nonfiction: The Message of Thomas Friedman’s New Book: It’s Going to Be O.K.
#
#
#
#             Books of The Times: Review: ‘Absolutely on Music’ Gives a Maestro a Stage for Ideas
#
#
#
#             Where Donald Trump Stands on School Choice, Student Debt and Common Core
#
#
#
#             At Iowa High School, Election Results Kindle Tensions and Protests
#
#
#
#             Restaurant Review: Thai Food Strikes Out in a Fresh Direction at Fish Cheeks
#
#
#
#             Cooking Up Conversation as Martha’s Vineyard Quiets Down
#
#
#
#             Editorial: Facebook and the Digital Virus Called Fake News
#
#
#
#             Ross Douthat: The Crisis for Liberalism
#
#
#
#             2016 Holiday Gift Guide
#
#
#
#             What You Get: $750,000 Homes in New Hampshire, Tennessee and New Mexico
#
#
#
#             Pumpkin Pie in Miami: Thanksgiving Flight Patterns
#
#
#
#             The Thanksgiving Recipes Googled in Every State
#
#
#
#             Holiday Feast: Feast in New York City
#
#
#
#             Feature: Billionaires vs. the Press in the Era of Trump
#
#
#
#             Ford Move, Cited as Victory by Trump, Has No Effect on U.S. Jobs
#
#
#
#             Wheels: At the Los Angeles Auto Show, an Industry Ponders Its Digital Future
#
#
#
#             A 150-Year-Old British Footwear Factory, Through the Lens of Martin Parr
#
#
#
#             The Season’s Brightest Bags
#
#
#
#             Insider Podcasts: Good, Bad and Mad: The Opinion Columnist Andrew Rosenthal on the News
#
#
#
#             Times Insider Photo Challenge: Caption This!
#
# Downtown Brooklyn: Commercial Center to Neighborhood
# Search for Homes for Sale or Rent
# Sell Your Home

# %%
response = requests.get("https://en.wikipedia.org/wiki/Wikipedia:Today%27s_featured_article/March_20,_2010")
parser = BeautifulSoup(response.text, "html.parser")

# %%
parser.find('div', attrs={'id':'mw-content-text'}).text
# Out:
# u'function mfTempOpenSection(id){var block=document.getElementById("mf-section-"+id);block.className+=" open-block";block.previousSibling.className+=" open-block";}\nNew York State Route\xa0174 is a state highway in the county of Onondaga, located in Central New York, United States. The highway is 16.70 miles (26.88\xa0km) long and passes through mostly rural regions. Route\xa0174 begins at an intersection with NY\xa041 in Borodino, a hamlet of Spafford. It heads northward for most of its length, except for short distances in the villages of Marcellus and Camillus. The route ends at a junction with NY\xa05 west of Camillus, at the west end of the Route\xa05 Camillus bypass. Route\xa0174 is located along a large mapped sedimentary bedrock unit, known as the Marcellus Formation. The formation is named for an outcrop found near the town of Marcellus, New York, during a geological survey in 1839. The road was first laid out in the early 19th century following the path of Nine Mile Creek, which connected several early settlements in Central New York. The northern half of the route, between the villages of Marcellus and Camillus, was later improved as a plank road in 1855 by a private corporation that collected tolls from travelers on the road. The state took over the maintenance of the road by the beginning of the 20th century. The former plank road and an extension south to Otisco Lake and southwest to Skaneateles Lake was first designated as Route\xa0174 in the 1930 state highway renumbering. (more...)\nRecently featured: Race Against Time: Searching for Hope in AIDS-Ravaged Africa \u2013 Nikolai Rimsky-Korsakov \u2013 Tom Crean\n\n\nArchive\nBy email\nMore featured articles...\n\n\n\n\n\n'
