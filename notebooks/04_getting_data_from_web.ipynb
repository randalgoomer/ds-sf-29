# %%
import sys
import requests     # how python goes onto the internet!
import re           # regex
from bs4 import BeautifulSoup # a python HTML parser (version 3)

# %%
import  bs4

# %%
# let's turn to stock prices
# http://finance.google.com/finance?q=aapl

# %%
symbol = 'aapl'

# %%
# Let's grab the raw html from the page
r = requests.get('http://finance.google.com/finance?q='+symbol) # the url of the google finance page goes in here

# %%
#b = BeautifulSoup(r.text,"html5lib")

# %%
# b = BeautifulSoup(r.text, "html5lib") # create a beautifulsoup object
b = BeautifulSoup(r.text, 'html.parser') # try this line instead if you have problems

# %%
b.prettify() # will print the html nicely
# Out:
# u'<!DOCTYPE html>\n<html>\n <head>\n  <script>\n   (function(){(function(){function e(a){this.t={};this.tick=function(a,c,b){var d=void 0!=b?b:(new Date).getTime();this.t[a]=[d,c];if(void 0==b)try{window.console.timeStamp("CSI/"+a)}catch(h){}};this.tick("start",null,a)}var a,d;window.performance&&(d=(a=window.performance.timing)&&a.responseStart);var f=0<d?new e(d):new e;window.jstiming={Timer:e,load:f};if(a){var c=a.navigationStart;0<c&&d>=c&&(window.jstiming.srt=d-c)}if(a){var b=window.jstiming.load;0<c&&d>=c&&(b.tick("_wtsrt",void 0,c),b.tick("wtsrt_","_wtsrt",\nd),b.tick("tbsd_","wtsrt_"))}try{a=null,window.chrome&&window.chrome.csi&&(a=Math.floor(window.chrome.csi().pageT),b&&0<c&&(b.tick("_tbnd",void 0,window.chrome.csi().startE),b.tick("tbnd_","_tbnd",c))),null==a&&window.gtbExternal&&(a=window.gtbExternal.pageT()),null==a&&window.external&&(a=window.external.pageT,b&&0<c&&(b.tick("_tbnd",void 0,window.external.startE),b.tick("tbnd_","_tbnd",c))),a&&(window.jstiming.pt=a)}catch(g){}})();}).call(this);\n  </script>\n  <title>\n   Apple Inc.: NASDAQ:AAPL quotes &amp; news - Google Finance\n  </title>\n  <meta content="Get detailed financial information on Apple Inc. (NASDAQ:AAPL) including real-time stock quotes, historical charts &amp; financial news, all for free!" name="Description">\n   <meta content="IE=10" http-equiv="X-UA-Compatible">\n    <link href="http://www.google.com/finance?cid=22144" rel="canonical">\n     <link href="/finance/f/finance_us-1489929081.css" rel="stylesheet" type="text/css">\n      <link href="/_/scs/finance-static/_/ss/k=finance.a.x7heix82rby5.L.W.O/d=0/rs=AGHGApFPN2TpOk8r5vkQgPd47Zv7Pkrwuw" rel="stylesheet" type="text/css">\n       <link href="/finance/favicon.ico" rel="icon" type="image/vnd.microsoft.icon">\n        <style>\n         #gbar,#guser{font-size:13px;padding-right:8px;padding-top:4px !important;}#gbar{padding-left:8px;height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}\n        </style>\n        <script>\n        </script>\n        <script async="" defer="" src="//www.google.com/insights/consumersurveys/async_survey?site=xusttduenzseze54mcajwbd6sq">\n        </script>\n        <script>\n         function _rpt() {}\n      function _tck() {}\n        </script>\n        <script>\n         (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n    ga(\'create\', \'UA-40765809-1\', {\n      \'allowLinker\': true,\n      \'cookiePath\': \'/finance\'\n    });\n    ga(\'send\', \'pageview\');\n        </script>\n       </link>\n      </link>\n     </link>\n    </link>\n   </meta>\n  </meta>\n </head>\n <body>\n  <div class="fjfe-bodywrapper">\n   <div class="g-doc" id="fjfe-real-body">\n    <input id="hist_state" name="hist_state" style="display:none;" type="text">\n     <iframe class="invfr" id="hist_frame" name="hist_frame" tabindex="-1">\n     </iframe>\n     <iframe class="invfr" src="/_/scs/finance-static/_/js/k=finance.a.en_US.9R147Dhnn8c.O/m=b/rt=h/d=0/rs=AGHGApGszSEHbMoXAq0_ObWO6zwfX-urUw" tabindex="-1">\n     </iframe>\n     <div id="gbar">\n      <nobr>\n       <a class="gb1" href="https://www.google.com/webhp?tab=ew">\n        Search\n       </a>\n       <a class="gb1" href="http://www.google.com/imghp?hl=en&amp;tab=ei">\n        Images\n       </a>\n       <a class="gb1" href="http://maps.google.com/maps?hl=en&amp;tab=el">\n        Maps\n       </a>\n ...

# %%
# find all span tags
b.findAll('span')
# b.find_all('span') for bs4 users
# Out:
# [<span class="gbi" id="gbn"></span>,
#  <span class="gbf" id="gbf"></span>,
#  <span id="gbe"></span>,
#  <span class="fjfe-searchbox-button-wrapper"><span class="fjfe-searchbox-button-wrapper2"><input class="fjfe-searchbox-button" tabindex="2" type="submit" value="Get quotes"/></span></span>,
#  <span class="fjfe-searchbox-button-wrapper2"><input class="fjfe-searchbox-button" tabindex="2" type="submit" value="Get quotes"/></span>,
#  <span class="fjfe-recentquotes-duration">(<a href="//www.google.com/history/optout?hl=en">30 days</a>)</span>,
#  <span class="fjfe-chg-toggle">chg</span>,
#  <span class="fjfe-perc-toggle">%</span>,
#  <span class="pr">\n<span id="ref_22144_l">110.52</span>\n</span>,
#  <span id="ref_22144_l">110.52</span>,
#  <span class="ch bld"><span class="chr" id="ref_22144_c">-0.94</span>\n<span class="chr" id="ref_22144_cp">(-0.84%)</span>\n</span>,
#  <span class="chr" id="ref_22144_c">-0.94</span>,
#  <span class="chr" id="ref_22144_cp">(-0.84%)</span>,
#  <span class="bld" id="ref_22144_el">110.52</span>,
#  <span class="chb" id="ref_22144_ec">0.00</span>,
#  <span class="chb" id="ref_22144_ecp">(0.00%)</span>,
#  <span class="dis-large"><nobr>NASDAQ\nreal-time data -\n<a class="dis-large" href="//www.google.com/help/stock_disclaimer.html#realtime">Disclaimer</a>\n</nobr></span>,
#  <span class="time">12:00PM EST</span>,
#  <span class="settings-link">Settings</span>,
#  <span class="technicals-link">Technicals</span>,
#  <span style="white-space:nowrap;">\n<img alt="Link to chart icon." class="linktochart-img SP_link" hight="9" src="/finance/s/m4C5KaofCbA/images/cleardot.gif" width="16"/>\n<span class="linktochart-link">\nLink to this view</span>\n</span>,
#  <span class="linktochart-link">\nLink to this view</span>,
#  <span class="chart-dis">Volume delayed by 15 mins.<br>Prices are not from all markets.<br>Sources include SIX.<br>\n</br></br></br></span>,
#  <span class="id-related-edit-col linkbtn">Add or remove columns</span>]

# %%
# the pattern we recognized from the website
re_tag = re.compile("ref_\d+_l")

# %%
#this tag finds the tag with the price in it!!!!
span_tag = b.find('span', attrs={'id': re_tag}) 
# use find to return THE ONE AND ONLY span tags with an id that matches our regex
# use findAll to find all matches

# %%
quote = span_tag.text
quote
# Out:
# u'110.52'

# %%
##### EXERCISE #####
# Make a method  get_stock_price that takes in ANY stock ticker and grabs the current price
# If the stock ticker doesn't exist, return -1

# %%
def get_stock_price(ticker):
    response = requests.get("http://google.com/finance?q="+ticker)
    parser = BeautifulSoup(response.text, "html.parser")
    pattern = re.compile("ref_\d+_l")
    span_tag = parser.find("span", attrs={"id":pattern})
    if span_tag:
        return span_tag.text
    else:
        return -1

# %%
for ticker in ['ge', 'spy', 'fb','rtn']:
    print get_stock_price(ticker)
# Out:
# 30.76
# 220.38
# 118.42
# 149.54

# %%
response = requests.get("http://www.nytimes.com/")
parser = BeautifulSoup(response.text, "html.parser")
for story in parser.findAll("h2", attrs={'class':'story-heading'}):
    print story.text
# Out:
# Trump Vows to Cede Business Role; Skeptics Still See Conflict
# Transition Briefing: Palin Eyed for V.A.? 4:50 PM ET
# Trump Team’s Tax Promises Will Be Hard to Achieve
#  What Saving 1,000 Jobs in Indiana Means
# C.I.A. Chief Warns Against Tearing Up Iran Deal
#
# Treasury Pick Comes From Hollywood; Trump Dines With Romney
# Snapshot Captures Trump and Romney’s Awkward Courtship 1:57 PM ET
# What Trump Might Do for Working-Class Families
# Flag Burners Should Lose Rights, Trump Says
# What (Lots of) Money Can Buy at Trump’s Inauguration
# Pelosi Beats Back House Democratic Leadership Challenge
# Mass Graves Dug by ISIS in Iraq Renew a Ghastly Ritual
#
# Charlotte Officer Won’t Face Charges in Fatal Shooting
# OPEC Agrees to Cut Oil Production for 1st Time in 8 Years
# U.S. Will Ban Smoking in Public Housing Nationwide
#
#                                     Students Mourn Castro
# Ohio State Attacker Likely ‘Inspired’ by ISIS or Al Qaeda, F.B.I. Says 4:01 PM ET
# U.N. Stiffens Sanctions on North Korea 11:16 AM ET
# Soccer Team’s Plane Crashes, Leaving Brazil Devastated
# Your Thursday Briefing
#
# California Today: A View of San Francisco From Space
# How to Get Your Home Ready for the Holidays
# The Season’s Best Travel Books
# San Bernardino Survivors Say County Health Plan Is ‘Victimizing’ Them Again
#
# How to Hide $400 Million
# How Snapchat Quietly Revolutionized Social Networks
# Mind Over Body: Playing in the N.F.L. at 38
# More Law Degrees for Women, but Fewer Good Jobs
# Judge Overturns ’91 Murder Conviction Over ‘Malfeasance’
#
# How America Ferrera Defied Her Inner Critic
#
#
# Beyond ‘Hamilton,’ for Better and for Worse
#
#
# Can Television Be Fair to Muslims?
#
# I Am a Dangerous Professor
# Editorial: Mr. Trump, Meet the Constitution
# Bruni: The Case for Romney
# Douthat: Can the Democrats Move Right?
# Op-Ed: Cities and States Lead on Climate Change
# Fidel Castro, a South African Hero
# Op-Ed: Appalachia Burning 11:57 AM ET
# Disability: The Dawn of the ‘Tryborg’
# Taking Note: Trump Shouldn’t Fill the Cabinet With Generals
#
# Decades in the Making: Fidel Castro’s Obituary
#
#
# How One Brutal Weekend in Chicago Lives on for Times Team
#
#
# Decades in the Making: Fidel Castro’s Obituary
#
#
# Play Today’s Puzzle
#
#
# Play Today’s Puzzle
#
#
# Come On Along With Us
#
# Raising 2 Young Children by Herself, in a Space That Feels Not Big Enough
# Skiing the Alps, Making It My Own
# Disability: The Dawn of the ‘Tryborg’
# Restaurant Review: Bad Saint in Washington
# Jimmy Carter: America Must Recognize Palestine
# Lens: Documenting the Genocide of Iraq’s Yazidis
# Skipping the Casinos, but Embracing Macau’s Past
# Is ‘Empathy’ Really What the Nation Needs?
# Op-Ed: Cities and States Lead on Climate Change
# Die Antwoord: Real Zef Rappers of Beverly Hills
# Brexit’s Bitter Winners
# David Foster Wallace’s Peaceful Prairie
# Beyond Beer: Germany Goes All In for Gin
#
#
#             Norcia Journal: Italian Monastery Seeks Salvation in Beer After Devastating Quake
#
#
#
#             Another Mass Grave Dug by ISIS in Iraq, and a Ghastly Ritual Renewed
#
#
#
#             Entrepreneurship: How Banza, a Chickpea Pasta Start-Up, Thrives on Attention
#
#
#
#             Trump Taps Hollywood’s Mnuchin for Treasury and Dines With Romney
#
#
#
#             Editorial: Mr. Trump, Meet the Constitution
#
#
#
#             Frank Bruni: The Case for Mitt Romney
#
#
#
#             Charlotte Officer ‘Acted Lawfully’ in Fatal Shooting of Keith Scott
#
#
#
#             F.D.A. Agrees to New Trials for Ecstasy as Relief for PTSD Patients
#
#
#
#             Snapchat’s Path to a Big Payday
#
#
#
#             Trying Snap’s Spectacles: Live With the Look, Enjoy the View
#
#
#
#             Critic's Notebook: The Far Right Has a New Digital Safe Space
#
#
#
#             Beyond ‘Hamilton,’ for Better and for Worse
#
#
#
#             Supreme Court Weighs Jailed Immigrants’ Right to Periodic Hearings
#
#
#
#             A Snapshot Captures the Awkward Courtship Between Trump and Romney
#
#
#
#             Celebrating Shoes With Rihanna
#
#
#
#             Skin Deep: ‘Instagram Face’: Is It the End of Good Makeup?
#
#
#
#             From ‘Rogue One’: A Rising Star in a Galaxy Far, Far Away
#
#
#
#             Roundup: This Season’s Best Books on Hollywood
#
#
#
#             Domestic Abuse Killings Climb as Murders Drop, Frustrating New York Officials
#
#
#
#             No Rainbow, but Thief Finds a Bucket of Gold on West 48th Street
#
#
#
#             Tiger Woods Is Back. He Brought Some Nerves, but Left the Pain at Home
#
#
#
#             On Baseball: Keeping Yoenis Cespedes, Mets Step Up to the Plate
#
#
#
#             Review: 5 Short Plays, Up-Close and Unsettled, Purposely
#
#
#
#             Beyond ‘Hamilton,’ for Better and for Worse
#
#
#
#             A Conversation With: C. Megan Urry, Peering Into Universe, Spots Bias on the Ground
#
#
#
#             Space’s Trash Collector? A Japanese Entrepreneur Wants the Job
#
#
#
#             Bruce Mazlish, Who Fused Psychoanalysis and History in His Books, Dies at 93
#
#
#
#             Russell Oberlin, Renowned Countertenor, Is Dead at 88
#
#
#
#             Watched All of the ‘Gilmore Girls’ Revival? Let’s Talk About It
#
#
#
#             Review: ‘Incorporated’ Travels to a Dystopian 2074
#
#
#
#             Insomniacs Are Helped by Online Therapy, Study Finds
#
#
#
#             Why Gunshot Victims Have Reason to Like the Affordable Care Act
#
#
#
#             Pursuits: With an Arsenal of Apps, a Fearful Flier Faces the Skies
#
#
#
#             Frugal Traveler: In Macau, Skipping the Casinos, but Embracing the Past
#
#
#
#             Books of The Times: ‘Born a Crime,’ Trevor Noah’s Raw Account of Life Under Apartheid
#
#
#
#             100 Notable Books of 2016
#
#
#
#             Professor Watchlist Is Seen as Threat to Academic Freedom
#
#
#
#             A Bronx Librarian Keen on Teaching Homeless Children a Lasting Love of Books
#
#
#
#             Museum Cafeteria Serves Black History and a Bit of Comfort
#
#
#
#             Restaurant Review: Filipino Food Worth the Wait at Bad Saint in Washington
#
#
#
#             Editorial: Can Senate Democrats Save the Party?
#
#
#
#             Frank Bruni: The Pretend Populism of Donald Trump
#
#
#
#             International Real Estate: House Hunting in ... Milan
#
#
#
#             What You Get: $2,500,000 Homes in Wyoming, Virginia and California
#
#
#
#             The 2016 Race: ‘Serious Voter Fraud’? Um, No
#
#
#
#             The New Health Care: When Having Insurance Still Leaves You Dangerously Uncovered
#
#
#
#             Talk: Why Iggy Pop Traded In His Sports Car
#
#
#
#             The Ethicist: Should I Call My Friend Out for Her ‘Service Dog’ Scam?
#
#
#
#             Wheels: Dull Car Finish Now Shines
#
#
#
#             Lapo Elkann, Italian Scion and Fashion Designer, Is Arrested in Manhattan
#
#
#
#             Neon Gear and Renegade Style: The Heyday of Snowboarding
#
#
#
#             The Freshmen: Four Art Basel Miami First-Timers to Know
#
#
#
#             Decades in the Making: Fidel Castro’s Obituary
#
#
#
#             Times Insider Photo Challenge: Caption This!
#
# West Chelsea: From Industrial to Chic
# Search for Homes for Sale or Rent
# Sell Your Home

# %%
response = requests.get("https://en.wikipedia.org/wiki/Wikipedia:Today%27s_featured_article/March_20,_2010")
parser = BeautifulSoup(response.text, "html.parser")

# %%
parser.find('div', attrs={'id':'mw-content-text'}).text
# Out:
# u'function mfTempOpenSection(id){var block=document.getElementById("mf-section-"+id);block.className+=" open-block";block.previousSibling.className+=" open-block";}\nNew York State Route\xa0174 is a state highway in the county of Onondaga, located in Central New York, United States. The highway is 16.70 miles (26.88\xa0km) long and passes through mostly rural regions. Route\xa0174 begins at an intersection with NY\xa041 in Borodino, a hamlet of Spafford. It heads northward for most of its length, except for short distances in the villages of Marcellus and Camillus. The route ends at a junction with NY\xa05 west of Camillus, at the west end of the Route\xa05 Camillus bypass. Route\xa0174 is located along a large mapped sedimentary bedrock unit, known as the Marcellus Formation. The formation is named for an outcrop found near the town of Marcellus, New York, during a geological survey in 1839. The road was first laid out in the early 19th century following the path of Nine Mile Creek, which connected several early settlements in Central New York. The northern half of the route, between the villages of Marcellus and Camillus, was later improved as a plank road in 1855 by a private corporation that collected tolls from travelers on the road. The state took over the maintenance of the road by the beginning of the 20th century. The former plank road and an extension south to Otisco Lake and southwest to Skaneateles Lake was first designated as Route\xa0174 in the 1930 state highway renumbering. (more...)\nRecently featured: Race Against Time: Searching for Hope in AIDS-Ravaged Africa \u2013 Nikolai Rimsky-Korsakov \u2013 Tom Crean\n\n\nArchive\nBy email\nMore featured articles...\n\n\n\n\n\n'
