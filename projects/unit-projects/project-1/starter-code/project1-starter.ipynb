# %% [markdown]
# # Project 1
#
# In this first project you will create a framework to scope out data science projects. This framework will provide you with a guide to develop a well-articulated problem statement and analysis plan that will be robust and reproducible.

# %% [markdown]
# ### Read and evaluate the following problem statement:
# Determine which free-tier customers will covert to paying customers, using demographic data collected at signup (age, gender, location, and profession) and customer useage data (days since last log in, and activity score 1 = active user, 0= inactive user) based on Hooli data from Jan-Apr 2015.

# %% [markdown]
# #### 1. What is the outcome?

# %% [markdown]
# Answer: conversion to paying customers

# %% [markdown]
# #### 2. What are the predictors/covariates?

# %% [raw]
# Answer:
# 1) demographic data such as: age, gender, location and profession &
# 2) Usage data such as: activity score

# %% [markdown]
# #### 3. What timeframe is this data relevent for?

# %% [raw]
# Answer:
# Jan - Apr 2015

# %% [markdown]
# #### 4. What is the hypothesis?

# %% [raw]
# Answer:
# H = Demographic data is predictor of customer purchasing behavior

# %% [markdown]
# ## Let's get started with our dataset

# %% [markdown]
# #### 1. Create a data dictionary

# %% [raw]
# Answer:
#
# Variable | Description | Type of Variable
# ---| ---| ---
# Admit.   | admit =1 or not admit= 0  | binary
# GRE      | GRE score range 0 - 800   | continuous
# GPA      | GPA score range 0 - 4.00  | continous
# Rank     | Alma mater, hi(1) - Lo(4) | categorical

# %% [markdown]
# We would like to explore the association between X and Y

# %% [markdown]
# #### 2. What is the outcome?

# %% [raw]
# Answer: Binary (Admit(1) or  not Admit(0))

# %% [markdown]
# #### 3. What are the predictors/covariates?

# %% [raw]
# Answer: GRE, GPA, Rank, Admit

# %% [markdown]
# #### 4. What timeframe is this data relevent for?

# %% [raw]
# Answer: time-frame not given;

# %% [markdown]
# #### 4. What is the hypothesis?

# %% [raw]
# Answer: H = GRE, GPA and school rank can predict admit decision

# %% [markdown]
#     Using the above information, write a well-formed problem statement.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Exploratory Analysis Plan

# %% [raw]
# Using the lab from a class as a guide, create an exploratory analysis plan.

# %% [markdown]
# #### 1. What are the goals of the exploratory analysis?

# %% [raw]
# Answer: To adress the hypothesis that: GRE, GPA and Prestige of undergrad Alma mater can predict admit decision. To analyze data set to find its main characteristics with visual and graphical methods.

# %% [markdown]
# #### 2a. What are the assumptions of the distribution of data?

# %% [raw]
# Answer: Normal distribution of gre and gpa may be assumed if mean is close to median. Also, for normal data, skewness will be low and kurtosis will be positive. Binary decision outcome will be assumed for admit.

# %% [markdown]
# #### 2b. How will determine the distribution of your data?

# %% [raw]
# Answer: compare data.mean() with data.median and skewness and kurtosis of the data for variables (gre, gpa, prestige vs admit)

# %% [markdown]
# #### 3a. How might outliers impact your analysis?

# %% [raw]
# Answer: Outliers will primarily affect the mean but not median. Outliers will also increase the skew() and kurtosis() will be reduced.

# %% [markdown]
# #### 3b. How will you test for outliers?

# %% [raw]
# Answer: graphically (histograms and density plots); mean vs. median analysis. skewness and kurtosis.

# %% [markdown]
# #### 4a. What is colinearity?

# %% [raw]
# Answer: Variables are colinear, when two or more variables increase or descrease in concert with each other.

# %% [markdown]
# #### 4b. How will you test for colinearity?

# %% [raw]
# Answer:
# collinearity can be tested by 'kde' maps, shown below. Also by r-square analysis amongst the variables in question. if r-square is high, implies collinear relationship.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

admission = pd.read_csv ('~/Desktop/ds-sf-29/projects/unit-projects/project-1/assets/admissions.csv', float_precision=2)

# %%
adission_grouped = admission.groupby('admit')

# %% [markdown]
# #### 5. What is your exploratory analysis plan?
# Using the above information, write an exploratory analysis plan that would allow you or a colleague to reproduce your analysis 1 year from now.

# %% [raw]
# Answer:
# 3) test for normal distribution by plotting, mean(), median(), skew(), kurtosis() tests and comparisons.
# 4) colinearity by 'scatterplot'

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(admission, alpha=0.2, figsize=(6, 6), diagonal='kde')
#kde = kernel density estmation
plt.show()

# %%
adission_grouped['gre'].plot(kind="density")
plt.legend()
plt.title('GRE')

# %%
adission_grouped['prestige'].plot(kind="density" )
plt.legend()
plt.title('prestige')

# %%
adission_grouped['gpa'].plot(kind="density" )
plt.legend()
plt.title('GPA')

# %% [markdown]
# ## Bonus Questions:
# 1. Outline your analysis method for predicting your outcome
# 2. Write an alternative problem statement for your dataset
# 3. Articulate the assumptions and risks of the alternative model

# %%
admission_admit = admission[admission['admit']==1]
print admission_admit.head()
# Out:
#    admit    gre   gpa  prestige
# 1    1.0  660.0  3.67       3.0
# 2    1.0  800.0  4.00       1.0
# 3    1.0  640.0  3.19       4.0
# 5    1.0  760.0  3.00       2.0
# 6    1.0  560.0  2.98       1.0

# %%
admission_no_admit = admission[admission['admit']==0]
print admission_no_admit.head()
# Out:
#     admit    gre   gpa  prestige
# 0     0.0  380.0  3.61       3.0
# 4     0.0  520.0  2.93       4.0
# 7     0.0  400.0  3.08       2.0
# 9     0.0  700.0  3.92       2.0
# 10    0.0  800.0  4.00       4.0

# %%
# Hypothesis-null: GRE score is not significant for admission.
# Hypothesis-alternate: GRE score is significant for admission.

admit_mean = admission_admit['gre'].mean()
admit_stdv = admission_admit['gre'].std()
no_admit_mean = admission_no_admit['gre'].mean()
no_admit_stdv = admission_no_admit['gre'].std()
admit_n = (len(admission_admit['admit']))
no_admit_n = (len(admission_no_admit['admit']))
print admit_n
print no_admit_n
print (admit_mean)
print (admit_stdv)
print (no_admit_mean)
print (no_admit_stdv)
if admit_mean > no_admit_mean:
    print "Alternate hypothesis( that GRE is higher for admission )is accepted"
# Out:
# 127
# 273
# 618.897637795
# 108.884884214
# 573.579335793
# 116.052798397
# Alternate hypothesis( that GRE is higher for admission )is accepted

# %%
# Hypothesis-null: GPA score is not significant for admission.
# Hypothesis-alternate: GPA score is significant for admission.

admit_mean = admission_admit['gpa'].mean()
admit_stdv = admission_admit['gpa'].std()
no_admit_mean = admission_no_admit['gpa'].mean()
no_admit_stdv = admission_no_admit['gpa'].std()
admit_n = (len(admission_admit['admit']))
no_admit_n = (len(admission_no_admit['admit']))
print admit_n
print no_admit_n
print (admit_mean)
print (admit_stdv)
print (no_admit_mean)
print (no_admit_stdv)
if admit_mean > no_admit_mean:
    print "Alternate hypothesis( that GPA is higher for admission )is accepted"
# Out:
# 127
# 273
# 3.48920634921
# 0.371654900518
# 3.34540441176
# 0.376772835309
# Alternate hypothesis( that GPA is higher for admission )is accepted

# %%
# Hypothesis-null: prestige is not significant for admission.
# Hypothesis-alternate: prestige is significant for admission.

admit_mean = admission_admit['prestige'].mean()
admit_stdv = admission_admit['prestige'].std()
no_admit_mean = admission_no_admit['prestige'].mean()
no_admit_stdv = admission_no_admit['prestige'].std()
admit_n = (len(admission_admit['admit']))
no_admit_n = (len(admission_no_admit['admit']))
print admit_n
print no_admit_n
print (admit_mean)
print (admit_stdv)
print (no_admit_mean)
print (no_admit_stdv)
if admit_mean > no_admit_mean:
    print "Alternate hypothesis( that Prestige is higher for admission )is accepted"
else:
    print "Alternate hypothesis( that Prestige is higher for admission )is rejected"
# Out:
# 127
# 273
# 2.15079365079
# 0.921455026075
# 2.64102564103
# 0.917197844181
# Alternate hypothesis( that Prestige is higher for admission )is rejected
